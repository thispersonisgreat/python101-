# %% [markdown]
# <a href="https://colab.research.google.com/github/thispersonisgreat/python101-/blob/main/gas_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('gasprices.txt','r') as f: 
    f=[x.strip() for x in f.readlines()]
dates=[(x.split('-')[0],x.split('-')[-1].split(':')[0], x.split(':')[1]) for x in f]
print(dates)
# Out:
# [('\ufeff04', '1993', '1.068'), ('04', '1993', '1.079'), ('04', '1993', '1.079'), ('04', '1993', '1.086'), ('05', '1993', '1.086'), ('05', '1993', '1.097'), ('05', '1993', '1.106'), ('05', '1993', '1.106'), ('05', '1993', '1.107'), ('06', '1993', '1.104'), ('06', '1993', '1.101'), ('06', '1993', '1.095'), ('06', '1993', '1.089'), ('07', '1993', '1.086'), ('07', '1993', '1.081'), ('07', '1993', '1.075'), ('07', '1993', '1.069'), ('08', '1993', '1.062'), ('08', '1993', '1.06'), ('08', '1993', '1.059'), ('08', '1993', '1.065'), ('08', '1993', '1.062'), ('09', '1993', '1.055'), ('09', '1993', '1.051'), ('09', '1993', '1.045'), ('09', '1993', '1.047'), ('10', '1993', '1.092'), ('10', '1993', '1.09'), ('10', '1993', '1.093'), ('10', '1993', '1.092'), ('11', '1993', '1.084'), ('11', '1993', '1.075'), ('11', '1993', '1.064'), ('11', '1993', '1.058'), ('11', '1993', '1.051'), ('12', '1993', '1.036'), ('12', '1993', '1.018'), ('12', '1993', '1.003'), ('12', '1993', '0.999'), ('01', '1994', '0.
# ...
